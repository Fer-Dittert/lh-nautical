# %%
import pandas as pd

# Ler a tabela
df = spark.table("lh_nautical.04_gold.fct_vendas")

# Converter para pandas
pdf = df.toPandas()

# Salvar primeiro no disco local do driver
pdf.to_csv("/tmp/fct_vendas.csv", index=False)

print("Arquivo salvo em /tmp/fct_vendas.csv")

# %%
df = spark.table("lh_nautical.04_gold.fct_vendas")

pdf = df.toPandas()

pdf.to_csv("fct_vendas.csv", index=False)

# %%
df = spark.table("lh_nautical.04_gold.fct_vendas")

pdf = df.toPandas()

pdf.to_csv("/tmp/fct_vendas.csv", index=False)

print("Arquivo salvo em /tmp/fct_vendas.csv")

# %%
df = spark.table("lh_nautical.04_gold.fct_vendas")

pdf = df.toPandas()

pdf.to_csv("fct_vendas.csv", index=False)

import os
os.listdir()

# %%
displayHTML('<a href="files/fct_vendas.csv">Download arquivo</a>')

# %%
df = spark.table("lh_nautical.04_gold.fct_vendas")

pdf = df.toPandas()

pdf.to_csv("fct_vendas.csv", index=False)

pdf.head()

# %%
display(pdf)

# %%
df = spark.table("lh_nautical.04_gold.dim_cliente")
pdf = df.toPandas()
display(pdf)

# %%
df = spark.table("lh_nautical.04_gold.dim_data")
pdf = df.toPandas()
display(pdf)

# %%
df = spark.table("lh_nautical.04_gold.dim_produto")
pdf = df.toPandas()
display(pdf)

# %%
df = spark.table("lh_nautical.04_gold.fct_prejuizo_produto")
pdf = df.toPandas()
display(pdf)

# %%
df = spark.table("lh_nautical.04_gold.mart_categoria_top10_clientes")
pdf = df.toPandas()
display(pdf)

# %%
df = spark.table("lh_nautical.04_gold.mart_clientes_fieis")
pdf = df.toPandas()
display(pdf)

# %%
# %sql
SELECT
    SUM(receita_transacao_brl) AS receita_total,
    SUM(custo_total_brl) AS custo_total,
    SUM(prejuizo_brl) AS prejuizo_total
FROM lh_nautical.04_gold.fct_vendas;
